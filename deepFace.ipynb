# %%
from deepface import DeepFace
import cv2
import  matplotlib.pyplot as plt
from rich import print

# %%
img_path = 'womanw.jpeg'
img = cv2.imread(img_path)
plt.imshow(img[:, :, ::-1])

# %%
demography = DeepFace.analyze(img_path)
emotion = demography['dominant_emotion']
age = demography['age']

print(f'[pearl white bold]you are feeling: [pearl white bold]{emotion}')
print(f'[pearl white bold]you are: [pearl+]{age} years old')
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.43it/s]
# you are feeling: happy
# you are: 43 years old
